# %%
from collections import Counter
from pathlib import Path

import pandas as pd

from src.api.api import GraylogAPIProcessor
from src.processor.log_procesor import LogProcessor
from src.utils import guardarExcel

# %% [markdown]
# ### Fuente de vías en PRE

# %%
# df_ram = pd.read_csv("data/lineas_ram.txt", sep="\t").drop_duplicates()
# df_ram["Código"].value_counts()

# %%
# train_types = {
#     "Approach": "APROXIMACIÓN",
#     "Arrival": "LLEGADA",
#     "Departure": "SALIDA",
#     "Elimination": "BAJA",
#     "End": "FIN",
#     # "Entry": "ENTRY",
#     # "Exit": "EXIT",
#     "Maneuver": "MANIOBRA",
#     "Platform": "ALTA",
#     # "PlatformForecast": "PREDICCIÓN",
#     # "Stopped": "STOP",
#     # "TrackingLost": "LOST_TRACK",
# }
train_types = {}
mov_sorter = {
    v: k
    for k, v in enumerate(
        [
            "APROXIMACIÓN",
            "MANIOBRALLEGADA",
            "LLEGADA",
            "FIN",
            "BAJA",
            "ALTA",
            "SALIDA",
            "MANIOBRASALIDA",
            "MANIOBRA",
        ]
    )
}
api = GraylogAPIProcessor()
log_processor = LogProcessor()
log_list = api.loadMSELog(
    Path(
        r"C:\Users\jose.espinosa\Documents\Data\xsiv\PRE\2024-04\graylog 2024-04-17-170032 - 2024-04-18-101805.csv"
        # "data/graylogXSIV_RAM.csv"
    ),
    train_types,
    train_operator=None,
)
# # df_logs = log_processor.getLogsInfoMSE([log_list], train_types)
# Out:
#   0%|          | 0/487849 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 85
#      44 codigos = [
#      45     "04028",
#      46     "04020",
#    (...)
#      80     "04307",
#      81 ]
#      82 # df_ram = pd.read_csv("data/lineas_ram.txt", sep="\t").drop_duplicates()
#      83 # codigos = df_ram["Código"]
#      84 logs_pre = log_list.loc[
# --→ 85     (log_list["controlPoint_pointCode"].isin(codigos))
#      86     # & (log_list["trainProduct"].str.contains("RAM")),
#      87     # :,
#      88     [
#      89         "timestamp",
#      90         "movementType",
#      91         "trainProduct",
#      92         "trainCode",
#      93         "controlPoint_pointName",
#      94         "controlPoint_pointCode",
#      95         "platform_source",
#      96         "platform_platformCode",
# ...

# %%
codigos = [
    "71801",
    "79009",
    "71802",
    "B7181",
    "78402",
    "78501",
    "78502",
    "78503",
    "78504",
    "78505",
    "78506",
    "78706",
    "78707",
    "78708",
    "78500",
    "78605",
    "78606",
    "78607",
    "78609",
    "78600",
    "78403",
    "78703",
    "78704",
    "78705",
    "78709",
    "78604",
    "78404",
    "78405",
    "78406",
    "78407",
    "78408",
    "78610",
    "78700",
    "78701",
    "78702",
    "78710",
    "79502",
    "79600",
    "79403",
    "79404",
    "79606",
    "77107",
    "79101",
    "77105",
    "79601",
    "79603",
    "79407",
    "79408",
    "79409",
    "77103",
    "79303",
    "79304",
    "79007",
    "79100",
    "79109",
    "79206",
    "79205",
    "79300",
    "77006",
    "77100",
    "77306",
    "77307",
    "79102",
    "79011",
    "77102",
    "79005",
    "77110",
    "79605",
    "77002",
    "77003",
    "77004",
    "79107",
    "79200",
    "79607",
    "79405",
    "79406",
    "79006",
    "79500",
    "79501",
    "77005",
    "79604",
    "79608",
# # )
cuentas = (
    logs_pre[["controlPoint_pointName", "controlPoint_pointCode", "platform_source"]]
    .dropna()
    .groupby(["controlPoint_pointName", "controlPoint_pointCode"])
    .agg(Counter)
    .reset_index()
)
cuentas["total"] = cuentas["platform_source"].apply(lambda x: sum(x.values()))
cuentas["CTC"] = cuentas["platform_source"].apply(lambda x: x.get("CTC", 0))
cuentas["PLANIFICACIÓN"] = cuentas["platform_source"].apply(
    lambda x: x.get("PLANIFICACION", 0)
)
cuentas["CTC %"] = cuentas["CTC"] / cuentas["total"] * 100
cuentas["PLANIFICACIÓN %"] = cuentas["PLANIFICACIÓN"] / cuentas["total"] * 100
guardarExcel(
    cuentas[
        [
            "controlPoint_pointName",
            "controlPoint_pointCode",
            "total",
            "CTC",
            "PLANIFICACIÓN",
            "CTC %",
            "PLANIFICACIÓN %",
        ]
    ],
    Path("Fuentes_vías.xlsx"),
    sheet_name="Barcelona",
)

# %%
log_list.loc[
    # (log_list["controlPoint_pointCode"].isin(codigos)),
    # & (log_list["trainProduct"].str.contains("RAM")),
    :,
    [
        "timestamp",
        "movementType",
        "trainProduct",
        "trainCode",
        "controlPoint_pointName",
        "controlPoint_pointCode",
        "platform_source",
        "platform_platformCode",
        "timeToArrive_approachingTime",
        "movementSource_source",
        "movementType_type",
    ],
].dropna(subset=["platform_source"])#["platform_source"].value_counts()
# Out:
#                             timestamp    movementType    trainProduct  \
# 0       2024-04-17T17:28:47.000+02:00    trainArrival  Material Vacio
# 1       2024-04-18T10:16:14.000+02:00    trainArrival  Material Vacio
# 2       2024-04-18T05:43:52.000+02:00   trainApproach  Material Vacio
# 3       2024-04-18T08:25:31.000+02:00  trainDeparture       CERCANIAS
# 4       2024-04-17T19:25:20.000+02:00  trainDeparture          T.L.E.
# ...                               ...             ...             ...
# 487844  2024-04-17T20:16:09.891+02:00   trainManeuver       CERCANIAS
# 487845  2024-04-17T20:16:11.000+02:00  trainDeparture       CERCANIAS
# 487846  2024-04-17T20:16:12.000+02:00  trainDeparture    REGIONAL RAM
# 487847  2024-04-17T20:16:12.000+02:00    trainArrival       CERCANIAS
# 487848  2024-04-17T20:16:11.379+02:00   trainManeuver   CERCANIAS RAM
#
#        trainCode        controlPoint_pointName controlPoint_pointCode  \
# ...

# %%
# pd.to_datetime(log_list["timestamp"]).max()
# 2024-03-21 18:34 a 2024-03-22 10:16

# %%
# guardarExcel(
#     cuentas[
#         [
#             "controlPoint_pointName",
#             "controlPoint_pointCode",
#             "total",
#             "CTC",
#             "PLANIFICACIÓN",
#             "CTC %",
#             "PLANIFICACIÓN %",
#         ]
#     ],
#     Path("Fuentes_vías_MSE207.xlsx"),
# )

# %%
pd.to_datetime(1709325262000, unit="ms"), pd.to_datetime(1710521348000, unit="ms"),
# Out:
# (Timestamp('2024-03-01 20:34:22'), Timestamp('2024-03-15 16:49:08'))

# %%
# for fname in Path(r"C:\Users\jose.espinosa\Documents\Data\mie_mse").iterdir():
#     if not fname.is_file():
#         continue
#     fname.rename(fname.parent.joinpath(fname.name.replace(".log.", " 2024-03-")))
